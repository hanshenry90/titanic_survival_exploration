# %%
x = [1, 2, 3, 4, 5.5, 6]

# %%
print x
# Out:
# [1, 2, 3, 4, 5.5, 6]

# %%
import numpy as np
t = np.ones(6)
print t
y = np.array(x)
print y
# Out:
# [ 1.  1.  1.  1.  1.  1.]
# [ 1.   2.   3.   4.   5.5  6. ]

# %%
np.mean(y)
# Out:
# 3.5833333333333335

# %%
np.min(y)
# Out:
# 1.0

# %%
import matplotlib.pyplot as plt
plt.plot(t, y)
plt.show()

# %%
bmi = t/y **2
print bmi
# Out:
# [ 1.          0.25        0.11111111  0.0625      0.03305785  0.02777778]

# %%
print bmi.shape
# Out:
# (6,)

# %%
bmi[bmi > 0.2]
# Out:
# array([ 1.  ,  0.25])

# %%
z = np.array([9,8,7,6,5,4])

# %%
c = z * 2.2
print c
# Out:
# [ 19.8  17.6  15.4  13.2  11.    8.8]

# %%
"""Data School: dataFrame"""

import pandas as pd
df = pd.DataFrame({'id':[100, 101, 102], 'color':['red', 'blue', 'red']}, columns=['id', 'color'], index=['a', 'b', 'c'])
df # dictionary as table columns by key and value
# Out:
#     id color
# a  100   red
# b  101  blue
# c  102   red

# %%
pd.DataFrame([[100, 'red'], [101, 'blue'], [102, 'red']], columns=['id', 'color']) # list within list as table rows
# Out:
#     id color
# 0  100   red
# 1  101  blue
# 2  102   red

# %%
arr = np.random.rand(4, 2)
arr
# Out:
# array([[ 0.04883054,  0.64917252],
#        [ 0.35123451,  0.93349758],
#        [ 0.91596398,  0.08044943],
#        [ 0.01614517,  0.84294948]])

# %%
pd.DataFrame(arr, columns=['one', 'two'])
# Out:
#         one       two
# 0  0.048831  0.649173
# 1  0.351235  0.933498
# 2  0.915964  0.080449
# 3  0.016145  0.842949

# %%
pd.DataFrame({'student': np.arange(100, 110, 1), 'test': np.random.randint(60, 101, 10)}).set_index('student')
# Out:
#          test
# student
# 100        90
# 101        97
# 102        72
# 103        68
# 104        85
# 105        85
# 106        76
# 107        94
# 108        74
# 109        90

# %%
s = pd.Series(['round', 'square'], index=['c', 'b'], name='shape')
s
# Out:
# c     round
# b    square
# Name: shape, dtype: object

# %%
df
# Out:
#     id color
# a  100   red
# b  101  blue
# c  102   red

# %%
pd.concat([df, s], axis=1)
# Out:
#     id color   shape
# a  100   red     NaN
# b  101  blue  square
# c  102   red   round

# %%
pd.DataFrame([[1,2,3],[4,5,67]]) # list within list is by rows converted when converted to DF
# Out:
#    0  1   2
# 0  1  2   3
# 1  4  5  67

# %%
pd.DataFrame({'id':[1,2,3], 'age':[4,5,6]}) # dictionary is by columns when converted to DF
# Out:
#    age  id
# 0    4   1
# 1    5   2
# 2    6   3

# %%
pd.DataFrame({'id': (0,1) ,'name': ('johnson', 'mary')})
# Out:
#    id     name
# 0   0  johnson
# 1   1     mary

# %%
x = ('johson', 'mary')

# %%
print x
# Out:
# ('johson', 'mary')

# %%
pd.DataFrame({'johnson': {'slary': 40, 'age': 40, 'education': 'bechalor'},'mary': {'slary': 30, 'age': 30, 'education': 'bechalor'}})
# Out:
#             johnson      mary
# age              40        30
# education  bechalor  bechalor
# slary            40        30

# %%
"""How do I select multiple rows and columns from a pd DataFrame?"""

ufo = pd.read_csv('http://bit.ly/uforeports')

# %%
ufo.head(3)
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
len(ufo)
# Out:
# 18241

# %%
ufo.loc[1,:]
# Out:
# City                   Willingboro
# Colors Reported                NaN
# Shape Reported               OTHER
# State                           NJ
# Time               6/30/1930 20:00
# Name: 1, dtype: object

# %%
ufo.loc[[0,1,2],:]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[0:1, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00

# %%
ufo.loc[0:2, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
ufo.loc[0:2, 'City':'State'] # range instead of list ['City', 'State']
# Out:
#           City Colors Reported Shape Reported State
# 0       Ithaca             NaN       TRIANGLE    NY
# 1  Willingboro             NaN          OTHER    NJ
# 2      Holyoke             NaN           OVAL    CO

# %%
df = pd.DataFrame(ufo) # not needed, ufo is already read into DataFrame

# %%
ufo.head(3).drop('State', axis=1)
# Out:
#           City Colors Reported Shape Reported             Time
# 0       Ithaca             NaN       TRIANGLE   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL  2/15/1931 14:00

# %%
ufo[ufo.City=='Oakland']
# Out:
#           City Colors Reported Shape Reported State              Time
# 1694   Oakland             NaN          CIGAR    CA   7/21/1968 14:00
# 2144   Oakland             NaN           DISK    CA    8/19/1971 0:00
# 4686   Oakland             NaN          LIGHT    MD     6/1/1982 0:00
# 7293   Oakland             NaN          LIGHT    CA   3/28/1994 17:00
# 8488   Oakland             NaN            NaN    CA   8/10/1995 21:45
# 8768   Oakland             NaN            NaN    CA  10/10/1995 22:40
# 10816  Oakland             NaN          LIGHT    OR   10/1/1997 21:30
# 10948  Oakland             NaN           DISK    CA  11/14/1997 19:55
# 11045  Oakland             NaN       TRIANGLE    CA   12/10/1997 1:30
# 12322  Oakland             NaN       FIREBALL    CA   10/9/1998 19:40
# 12941  Oakland             NaN       CYLINDER    CA   1/23/1999 21:30
# 16803  Oakland             NaN       TRIANGLE    MD    7/4/2000 23:00
# ...

# %%
ufo.loc[ufo.City=="Oakland", 'State'] # loc is better
# Out:
# 1694     CA
# 2144     CA
# 4686     MD
# 7293     CA
# 8488     CA
# 8768     CA
# 10816    OR
# 10948    CA
# 11045    CA
# 12322    CA
# 12941    CA
# 16803    MD
# 17322    CA
# Name: State, dtype: object

# %%
ufo[ufo.City=="Oakland"].State # chain indexing, causing problems
# Out:
# 1694     CA
# 2144     CA
# 4686     MD
# 7293     CA
# 8488     CA
# 8768     CA
# 10816    OR
# 10948    CA
# 11045    CA
# 12322    CA
# 12941    CA
# 16803    MD
# 17322    CA
# Name: State, dtype: object

# %%
"""iloc == integer position"""

ufo.iloc[:, [0, 3]]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# 5               Valley City    ND
# 6               Crater Lake    CA
# 7                      Alma    MI
# 8                   Eklutna    AK
# 9                   Hubbard    OR
# 10                  Fontana    CA
# 11                 Waterloo    AL
# 12                   Belton    SC
# 13                   Keokuk    IA
# 14                Ludington    MI
# 15              Forest Home    CA
# 16              Los Angeles    CA
# 17                Hapeville    GA
# 18                   Oneida    TN
# 19               Bering Sea    AK
# 20                 Nebraska    NE
# 21                      NaN    LA
# 22                      NaN    LA
# 23                Owensboro    KY
# 24               Wilderness    WV
# 25                San Diego    CA
# ...

# %%
ufo.iloc[:, 0:4] # exclusive on the last integer position. But loc is inclusive on both sides!
# Out:
#                        City Colors Reported Shape Reported State
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# 5               Valley City             NaN           DISK    ND
# 6               Crater Lake             NaN         CIRCLE    CA
# 7                      Alma             NaN           DISK    MI
# 8                   Eklutna             NaN          CIGAR    AK
# 9                   Hubbard             NaN       CYLINDER    OR
# 10                  Fontana             NaN          LIGHT    CA
# 11                 Waterloo             NaN       FIREBALL    AL
# 12                   Belton             RED         SPHERE    SC
# ...

# %%
ufo.columns
# Out:
# Index([u'City', u'Colors Reported', u'Shape Reported', u'State', u'Time'], dtype='object')

# %%
list(range(0, 4))
# Out:
# [0, 1, 2, 3]

# %%
ufo.iloc[0:3, :]
# Out:
#           City Colors Reported Shape Reported State             Time
# 0       Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1  Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2      Holyoke             NaN           OVAL    CO  2/15/1931 14:00

# %%
drinks = pd.read_csv('http://bit.ly/drinksbycountry', index_col='country')

# %%
drinks.head()
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent
# country
# Afghanistan                           0.0      Asia
# Albania                               4.9    Europe
# Algeria                               0.7    Africa
# Andorra                              12.4    Europe
# Angola                                5.9    Africa

# %%
drinks.iloc[1,0]
# Out:
# 89

# %%
drinks.ix['Albania', 0]
# Out:
# 89

# %%
ufo.ix[0:2, 0:2] # confusing at what to inclusive or exclusive
# Out:
#           City Colors Reported
# 0       Ithaca             NaN
# 1  Willingboro             NaN
# 2      Holyoke             NaN

# %%
ufo.loc[ufo['Shape Reported']=='OVAL']
# Out:
#                                 City Colors Reported Shape Reported State  \
# 2                            Holyoke             NaN           OVAL    CO
# 13                            Keokuk             NaN           OVAL    IA
# 39                       San Antonio             NaN           OVAL    NM
# 46                    South Portland             NaN           OVAL    ME
# 63                         Baltimore             NaN           OVAL    MD
# 68                           Seattle             NaN           OVAL    WA
# 83                             Raton             NaN           OVAL    NM
# 93                         Baltimore             NaN           OVAL    MD
# 97                      Conshohocken             NaN           OVAL    PA
# 119                    New York City             NaN           OVAL    NY
# 126                       Pittsburgh             NaN           OVAL    PA
# 127                       Kensington             NaN           OVAL    MD
# ...

# %%
ufo.ix[ufo.City=='Holyoke', [1,3]]
# Out:
#       Colors Reported State
# 2                 NaN    CO
# 771               NaN    MA
# 3221              NaN    MA
# 7982              NaN    MA
# 18211             NaN    MA

# %%
"""don't use the following shortcut to access dataframe"""

ufo[['City', 'State']]
# Out:
#                        City State
# 0                    Ithaca    NY
# 1               Willingboro    NJ
# 2                   Holyoke    CO
# 3                   Abilene    KS
# 4      New York Worlds Fair    NY
# 5               Valley City    ND
# 6               Crater Lake    CA
# 7                      Alma    MI
# 8                   Eklutna    AK
# 9                   Hubbard    OR
# 10                  Fontana    CA
# 11                 Waterloo    AL
# 12                   Belton    SC
# 13                   Keokuk    IA
# 14                Ludington    MI
# 15              Forest Home    CA
# 16              Los Angeles    CA
# 17                Hapeville    GA
# 18                   Oneida    TN
# 19               Bering Sea    AK
# 20                 Nebraska    NE
# 21                      NaN    LA
# 22                      NaN    LA
# 23                Owensboro    KY
# 24               Wilderness    WV
# 25                San Diego    CA
# ...

# %%
x = np.array(ufo[['State', 'City', 'Time']])

# %%
print x
# Out:
# [['NY' 'Ithaca' '6/1/1930 22:00']
#  ['NJ' 'Willingboro' '6/30/1930 20:00']
#  ['CO' 'Holyoke' '2/15/1931 14:00']
#  ...,
#  ['WI' 'Eagle River' '12/31/2000 23:45']
#  ['WI' 'Eagle River' '12/31/2000 23:45']
#  ['FL' 'Ybor' '12/31/2000 23:59']]

# %%
np.array(ufo)
# Out:
# array([['Ithaca', nan, 'TRIANGLE', 'NY', '6/1/1930 22:00'],
#        ['Willingboro', nan, 'OTHER', 'NJ', '6/30/1930 20:00'],
#        ['Holyoke', nan, 'OVAL', 'CO', '2/15/1931 14:00'],
#        ...,
#        ['Eagle River', nan, nan, 'WI', '12/31/2000 23:45'],
#        ['Eagle River', 'RED', 'LIGHT', 'WI', '12/31/2000 23:45'],
#        ['Ybor', nan, 'OVAL', 'FL', '12/31/2000 23:59']], dtype=object)
